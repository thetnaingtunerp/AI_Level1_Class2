# %%
import pandas as pd
import numpy as np

arr = [20, 30, 30, 60, "mg mg", 'aung aung']

arr1 = np.array([1,3,5,7])
arr2 = np.array([[20, 30, 40, 50], [1,3,5,7]])
dct = [
    {'name':'mg mg', 'phone': 255645, 'address':'Yangon'},
    {'name': 'aung aung', 'phone': 54554, 'Address':'Mdy'}
]

dct2 = {
    'Name': ['mg mg', 'aung aung'],
    'Phone': [565455, 4564545],
    'Address': ["Yangon", 'Mandalay']
}


arr1.ndim

# series, dataframe
df1 = pd.Series(arr1)

df2 = pd.DataFrame(dct)

print(df1)
print(df2)
print(arr2.shape)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = {
    'Department': ['IT', 'IT', 'HR', 'HR', 'Finance', 'Finance'],
    'Employee': ['A', 'Bcdef', 'C', 'D', 'E', 'F'],
    'Salary': [6000, 7000, 4000, 4500, 8000, 7500],
    'Bonus': [500, 600, 200, 250, 800, 750]
}

df = pd.DataFrame(data)


sns.scatterplot(data=df, x=df['Employee'], y=df['Bonus'])
a =sns.color_palette('PiYG', 6)
sns.palplot(a)

plt.show()
