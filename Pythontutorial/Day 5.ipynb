# %%
# Numpy lib 
# !pip install numpy

# %%
import numpy as np
a = [
    12,
    3,
    4,
    5,
    7,
    8]
arr1 = np.array([12,3,4,5,7,8])
arr2 = np.array([
    [1,3,5,7,9],
    [2,4,6,8,10],
    [10,20,30,40,50],

    ])

# %%
arr3 = np.array(
    [
        [[1,2,3],[2,4,6]],
        [[1,3,5],[5,10,15]]
     ]
)
arr3[0,1,:2]

# %%
arr1 = np.array([1,2,3])
arr2 = np.array([
    [[2,4,6],[3,6,9]],
    [[2,4,6],[3,6,9]],
    [[2,4,6],[3,6,9]],
    ])
print(arr2.shape)

np.sum(arr2, axis=1)

# %%
arr2 = np.array([
    [1,3,5,7,9],
    [2,4,6,8,10],
    [10,20,30,40,50],

    ])


np.transpose(arr2)
# Out:
# array([[ 1,  2, 10],
#        [ 3,  4, 20],
#        [ 5,  6, 30],
#        [ 7,  8, 40],
#        [ 9, 10, 50]])
