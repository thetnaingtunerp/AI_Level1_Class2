# %%
name = 20
num = 2.1
str = "Hello"
bol = True, False

print(name)

# %%
a = 2
b = 3
c = a*b
print(c)

# %%
a = 3
b = 3
a >= b

# %%
# input()
input("Enter your Name")

# %%
# if 
mark = int(input("Enter Mark"))
if mark > 80:
    print('helo')
    
elif mark > 50:
    print('pass')
    
elif mark> 30:
    print('modaration')

else:
    print("world")

# %%
name = "My Name is Mg Mg"

for num in name:
    print(num)

# %%
# List
lst =[20, 30, 2.4 , "mg mg"]#index number
st = {20, 30, 2.4 , "mg mg"} #no index
tp = (20, 30, 2.4 , "mg mg")#index number
dt = {'key':'values', 'name':'Mg Mg', 'phone':'098745'} #KV

# %%
lst =[20, 30, 2.4 , "mg mg"] #index number
lst[:3] #range +1

tp = (20, 30, 2.4 , "mg mg")
tp[:3]

st = {20, 30, 2.4 , "mg mg"}
st
# Out:
# {2.4, 20, 30, 'mg mg'}

# %%
st = {20, 30, 2.4, 20, 'mg mg' , "mg mg", 'aung aung'}
st
# Out:
# {2.4, 20, 30, 'aung aung', 'mg mg'}

# %%
dict = {'name': 'mg mg', 'addres':'yangon', 'ph':123123}

dict.values()
dict.keys()
dict.items()
# Out:
# dict_items([('name', 'mg mg'), ('addres', 'yangon'), ('ph', 123123)])

# %%
tp = (20, 2.4,30, 2.4 , "mg mg")

tp
# Out:
# (20, 2.4, 30, 2.4, 'mg mg')
